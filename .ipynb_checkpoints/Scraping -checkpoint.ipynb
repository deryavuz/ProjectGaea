# %% [markdown]
# ## Scraping for Amazon, Target data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import io

# %%
#Open the file


###### CSV STUFF HERE

# %%
# Function to extract Product Title
def get_title(soup):
     
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
 
        # Inner NavigatableString Object
        title_value = title.string
 
        # Title as a string value
        title_string = title_value.strip()
 
 
    except AttributeError:
        title_string = ""   
 
    return title_string
 
# Function to extract Product Price
def get_price(soup):
 
    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()
 
    except AttributeError:
 
        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()
 
        except:     
            price = ""  
 
    return price
 
# Function to extract Product Rating
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
 
# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
 
# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
 
    except AttributeError:
        available = "Not Available"
 
    return available    
 
 
if __name__ == '__main__':
 
    # Headers for request
    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                'Accept-Language': 'en-US'})
 
    # The webpage URL
    URL = "https://www.amazon.com/s?k=ppe&ref=nb_sb_noss_2"
     
    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "lxml")
 
    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
 
    # Store the links
    links_list = []
 
    # Loop for extracting links from Tag Objects
    for link in links:
        links_list.append(link.get('href'))
 
 
    # Loop for extracting product details from each link 
    for link in links_list:
 
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)
 
        new_soup = BeautifulSoup(new_webpage.content, "lxml")
    
        curr_title = get_title(new_soup)
        curr_price = get_price(new_soup)
        curr_stock = get_availability(new_soup)
         
        # Function calls to display all necessary product information
        print("Product Title =", curr_title)
        print("Product Price =", curr_price)
        #print("Product Rating =", get_rating(new_soup))
        #print("Number of Product Reviews =", get_review_count(new_soup))
        print("Availability =", curr_stock)
        print()
        print()
        
        
        with io.open('scraped_data', "w", encoding="utf-8") as f:
            f.write(f"{curr_title},") 
            f.write(f"{curr_price},") 
            f.write(f"{curr_stock},\n")
            f.close()
# Out:
# Product Title =
# Product Price =
# Availability = Not Available
#
#
# Product Title = 50 PCS Blue Face Masks, Non Woven Thick 3-Layers Breathable Facial Masks with Adjustable Earloop, Mouth and Nose Cover
# Product Price = $9.99
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask 20 PCS, Included on FDA EUA List, Filter Efficiency≥95%, 5 Layers Cup Dust Mask Against PM2.5 from Fire Smoke, Dust, for Men, Women, Essential Workers(Black)
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = 4 Item All-In-One Personal protection Kit - 10 PACK
# Product Price = $28.00
# Availability = In Stock.
#
#
# Product Title = 25 Pack KN95 Face Mask, Included on FDA EUA List, Filter Efficiency≥95%, 5-Ply Mask Protection Against PM2.5, Fire Smoke, Dust Cup Dust Mask Black
# Product Price = $49.74
# Availability = In Stock.
#
#
# Product Title = 25 Pack KN95 Face Mask, Included on FDA EUA List, Filter Efficiency≥95%, 5-Ply Mask Protection Against PM2.5, Fire Smoke, Dust Cup Dust Mask Black
# Product Price = $49.74
# Availability = In Stock.
#
#
# Product Title = TCP Global Salon World Safety - Black Safety Face Masks Disposable 3-Ply PPE
# Product Price = $9.96
# Availability = In Stock.
#
#
# Product Title = Disposable Isolation Gown Polypropylene Lab Gowns Knit Cuff Long Sleeve Blue 10 Pack
# Product Price = $20.54
# Availability = In Stock.
#
#
# Product Title = Ever Ready First Aid DYN2141-X10 Isolation Gown with Elastic Wrists, Universal Quantity, Yellow (Pack of 10)
# Product Price = $24.95
# Availability = In Stock.
#
#
# Product Title = PAGE ONE Disposable Isolation Suit,Long Front Zipper Elastic Waistband & Cuffs Protective Coverall Suit/L
# Product Price = $15.99
# Availability = In Stock.
#
#
# Product Title = Disposable Isolation Gown Size: Universal Qty: 50 per Case (Blue)
# Product Price = $109.99
# Availability = In Stock.
#
#
# Product Title = KwikSafety (Charlotte, NC) TURTLE SHELL COMBO (10 Vents) Standard Cap ANSI Hard Hat, Safety Glasses, Sunshade, Sweatband & Earplugs Construction Work PPE, Type1, Class C, WHITE
# Product Price = $25.99
# Availability = In Stock.
#
#
# Product Title = Shoe Covers Disposable -100 Pack（50 Pairs） Disposable Shoe & Boot Covers Waterproof Slip Resistant Shoe Booties (Large Size - up to US Men's 11 & US Women’s 12.5)
# Product Price =
# Availability = In Stock.
#
#
# Product Title = Blue Shoe Guys Premium Disposable Boot & Shoe Covers | 100 Pack | Durable, Water Resistant, Non-Slip, Non-Toxic, Recyclable, 100% Virgin Fabric | Stretchable Up To US Men's 12 & Women's 14 Shoe Sizes
# Product Price = $24.99
# Availability = In Stock.
#
#
# Product Title = Dssiy 100 Pack Disposable Hygienic Boot & Shoe Covers 100 pack(50 Pairs)|Waterproof Slip Resistant Non-Slip, Durable for Construction, Workplace, Indoor Carpet Floor Protection,One Size Fits Most.
# Product Price = $11.99
# Availability = In Stock.
#
#
# Product Title = hand2mind Polyethylene, Level 1, Disposable, Non-Surgical Isolation Gowns, Blue, Bag of 15
# Product Price = $14.44
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask 20 PCS, Included on FDA EUA List, Filter Efficiency≥95%, 5 Layers Cup Dust Mask Against PM2.5 from Fire Smoke, Dust, for Men, Women, Essential Workers(Black)
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = 10pcs Glasses Face Shield Reusable Goggle Shields Replaceable Anti Fog Shields Transparent Face Shield Protect Face and Eyes for Women and Men (10, Transparent)
# Product Price = $21.99
# Availability = In Stock.
#
#
# Product Title = Hotodeal KN95 Mask Safety Mask Comfort Breathable Mask Headband Style
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask 40 PCs, Included on FDA EUA List, Filter Efficiency≥95%, 5 Layers Cup Dust Mask, Masks Against PM2.5 from Fire Smoke, Dust, for Men, Women, Essential Workers(White)
# Product Price = $55.99
# Availability = In Stock.
#
#
# Product Title = PAGE ONE Disposable Isolation Suit,Long Front Zipper Elastic Waistband & Cuffs Protective Coverall Suit/L
# Product Price = $15.99
# Availability = In Stock.
#
#
# Product Title = InterMask ASTM Level 3 Disposable 3 Ply Face Masks, More Than 98% Filtration Efficiency, Box Of 50 pcs
# Product Price = $16.99
# Availability = In Stock.
#
#
# Product Title = NanoBio Protect Nasal Antiseptic | Reduces The Risk of Respiratory Infection | Kills 99.99% of Germs | 8 Hour Protection | Safe for Kids, Daily Use | Nasal Disinfectant | 40+ Uses | FSA/HSA Eligible
# Product Price = $24.95
# Availability = In Stock.
#
#
# Product Title = Blue Polyethylene Cover Gown - Case of 75 | 23GSM Disposable Fluid Resistant Gown with Sleeves, Over the Head and Waist Tie | Thumb Loop Enclosure for Increased Coverage | 75 gowns (5 boxes of 15)
# Product Price = $94.99
# Availability = In Stock.
#
#
# Product Title = Kimberly-Clark N95 Pouch Respirator (53358), Made in U.S.A, Universal Size, 50 Respirators/Bag
# Product Price = $57.90
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask 20Pcs, Included on FDA EUA List, 5 Layer Design Cup Dust Safety Masks, Breathable Protection Masks Against PM2.5 Dust Bulk for Adult, Men, Women, Indoor, Outdoor Use, Black
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask 40 PCs, Included on FDA EUA List, Filter Efficiency≥95%, 5 Layers Cup Dust Mask, Masks Against PM2.5 from Fire Smoke, Dust, for Men, Women, Essential Workers(White)
# Product Price = $55.99
# Availability = In Stock.
#
#
# Product Title = KLEENGUARD - 49309 KleenGuard Maverick Safety Eyewear
# Product Price = $8.43
# Availability = In Stock.
#
#
# Product Title = Reusable Half Face Cover NASUM Half Face Cover wiith Safety Glasses,Paint Face Cover for Painting, Machine Polishing, Welding and Other Work Protection(Medium)
# Product Price = $30.99
# Availability = In Stock.
#
#
# Product Title = Suave Hand Sanitizer Alcohol Based Kills 99.9% of Germs 10 oz,Pack of 6
# Product Price = $26.94
# Availability = In Stock.
#
#
# Product Title = Safety Face Shields 10 Pack, Protective Face Shield Mask with Clear Wide Visor, Lightweight Transparent Dustproof Windproof Full Face Shield, Elastic Band for Women Men with 2 Protective Films
# Product Price =
# Availability = In Stock.
#
#
# Product Title = 50-Pack Disposable Isolation Gown, FDA Registered, CE certified Level 2 PP & PE 40g, Fully Closed Double Tie Back, Knitted Cuffs, Fluid Resistant, Unisex
# Product Price =
# Availability = In Stock.
#
#
# Product Title = TCP Global Salon World Safety - Black, Pink, Blue, Aqua Colored Face Masks Variety Pack (50ea Color = 200 Masks) Breathable Disposable 3-Ply Protective PPE with Nose Clip and Ear Loops
# Product Price = $49.96
# Availability = In Stock.
#
#
# Product Title = Ever Ready First Aid DYN2141-X10 Isolation Gown with Elastic Wrists, Universal Quantity, Yellow (Pack of 10)
# Product Price = $24.95
# Availability = In Stock.
#
#
# Product Title = 2000 PCS Wholesale Bulk Disposable Face Masks Blue (40 Boxes, 50pcs/Box), 3-Layers Breathable Face Mask with Adjustable Earloop for Business PPE
# Product Price = $139.98
# Availability = In Stock.
#
#
# Product Title = Safety Goggles, Anti-Fog Eye Protection Glasses, Lightweight Dustproof Over-Glasses, Anti-Splash Goggles for Men and Women 3 Pack
# Product Price = $9.34
# Availability = In Stock.
#
#
# Product Title = 20-Pack Disposable Isolation Gown, FDA Registered, CE certified Level 2 PP & PE 40g, Fully Closed Double Tie Back, Knitted Cuffs, Fluid Resistant, Unisex
# Product Price =
# Availability = In Stock.
#
#
# Product Title = PAERDE Over Glasses Safety Glasses Antifog,Eye Goggles for Protection with Clear Lense for Work Men Women
# Product Price =
# Availability = In Stock.
#
#
# Product Title = Natural Uniforms Women's Workwear Lightweight Warm Up Jacket G102
# Product Price = $10.99 - $17.95
# Availability = Not Available
#
#
# Product Title = Hotodeal KN95 Mask Safety Mask Comfort Breathable Mask Headband Style
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = All-in-One Personal Protection Kits to GO - 10 Pack - With Plastic Gloves, Hand Cleansing Wipes, Disposable Face Mask
# Product Price = $24.98
# Availability = In Stock.
#
#
# Product Title = 50 Pcs KN95 Personal Disposable mask Respiratory Face Protection, Healthy Protector/Filter Against Dusts, Allergens, Fog Haze, Splattering Liquids, Anti-Odor
# Product Price =
# Availability = In Stock.
#
#
# Product Title = Face Shield for Protection with Glasses Reusable Clear Mask 10 PCS Anti-Fog No Installation Required with Comfortable Sponge and Elastic Band for Women Men
# Product Price = $14.99
# Availability = In Stock.
# Product Title = Shoe Covers Disposable -100 Pack（50 Pairs） Disposable Shoe & Boot Covers Waterproof Slip Resistant Shoe Booties (Large Size - up to US Men's 11 & US Women’s 12.5)
# Product Price =
# Availability = In Stock.
#
#
# Product Title = KN95 - 5 Layer Face Mask (10 pcs) – Included on FDA EUA List - Filtration>95% with Comfortable Elastic Ear Loop | Non-Woven Polypropylene Fabric, Protection for Essential Workers
# Product Price = $22.90
# Availability = In Stock.
#
#
# Product Title = Face Shields For Protection - Full Plastic Faceshields Guard Anti Fog Reusable PPE Transparent Safety Protective Clear Mask Medical Surgical Dental Eye Shield Women Men Kids - Made in USA - 3 Pack
# Product Price =
# Availability = In Stock.
#
#
# Product Title = ISAMANNER 100pcs Mouth Covers
# Product Price = $11.99
# Availability = In Stock.
#
#
# Product Title = WesGen 30Pcs KN95 Face Mask，5 Layers Cup Dust Mask with Elastic Earloop and Nose Bridge Clip，Vacuum Packing
# Product Price = $29.99
# Availability = In Stock.
#
#
# Product Title = OMK 2 Pcs Reusable Face Shields
# Product Price = $9.99
# Availability = In Stock.
#
#
# Product Title = Cleaing Disposable Isolation Gown 10 Pack with Knit Cuff, Universal Size, Blue
# Product Price = $21.48
# Availability = In Stock.
#
#
# Product Title = ProtectX Level 4 Disposable Isolation Gown, (Pack of 10)
# Product Price = $16.99
# Availability = In Stock.
#
#
# Product Title = Karalai Washable, Waterproof Isolation Gown - Reusable Up to 10 Washes | Universal Size | 10 per Case (Blue)
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = PPE Kit All-in-One Personal Protection Kits to GO,10 Pack
# Product Price =
# Availability = In Stock.
#
#
# Product Title = Zubrex 50 Pcs Disposable 3 Ply Safety Face Mask for Protection - with Nanofiber Lining Elastic Earloops, Lightweight Breathable Protective Anti-Dust Facial Masks Health School Office
# Product Price = $13.98
# Availability = In Stock.
#
#
# Product Title = BLScode Disposable Face Protective Masks, 3-Layer Facial Cover Masks with Elastic Ear Loops, Comfortable Universal Design for Adults & Kids, Suitable for Home, Office, Outdoor (Pack of 50)
# Product Price = $12.99
# Availability = In Stock.
#
#
# Product Title = PPE Kit(10 Pouches),Personal Protection Kit with Nitrile Gloves,Disposable Face Masks,Antibacterial Wipes
# Product Price =
# Availability = In Stock.
#
#
# Product Title = ZMDREAM Disposable Non-woven Isolation Gown with Knit Cuff & Waist Ties 10 count Blue
# Product Price = $19.99
# Availability = In Stock.
#
#
# Product Title = Dynatomy Face Shields, 10-pack, Made in USA, Full Coverage PPE by D'Addario (DFSM-1-10)
# Product Price = $25.10
# Availability = In Stock.
#
#
# Product Title = SMS Disposable Isolation Gown Splash Resistant with Hood White Medium
# Product Price = $19.99
# Availability = In Stock.
#
#
# Product Title = 200 pcs PPE Disposable Isolation Gown, One Size fit All, Protective Suit Coverall, Isolation Gowns, Disposable Isolation Clothing Breathable Latex Free Blue 200 pcs in a box
# Product Price = $200.00
# Availability = In Stock.
#
#
# Product Title = Bigox Face Mask Disposable Earloop Blue 50Pcs
# Product Price = $9.99
# Availability = In Stock.
#
#
# Product Title = TCP Global Salon World Safety - Kids Face Masks 150 Pk 3-Ply Protective PPE (5 Colors, 30 Each)
# Product Price = $29.96
# Availability = In Stock.
#
#
# Product Title = CapLens Full Face Shield Cap Accessory, Anti-Fog, Adjustable, Reusable, Slip onto Your Existing Cap Black
# Product Price = $16.95
# Availability = In stock on February 10, 2021.
#
#
# Product Title = Milliard Washable, Waterproof Isolation Gown - Reusable Up to 50 Washes | Universal Size | 10 per Case (White)
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = All-in-One Personal Protection Kits to GO - 10 Pack - With Plastic Gloves, Hand Cleansing Wipes, Disposable Face Mask
# Product Price = $24.98
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask 20Pcs, Included on FDA EUA List, 5 Layer Design Cup Dust Safety Masks, Breathable Protection Masks Against PM2.5 Dust Bulk for Adult, Men, Women, Indoor, Outdoor Use, Black
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = LASHA 20pcs 5 Layers Protective Dust Safety Masks Disposable Face Masks
# Product Price = $29.98
# Availability = In Stock.
#
#
# Product Title = PAGE ONE Disposable Isolation Suit,Long Front Zipper Elastic Waistband & Cuffs Protective Coverall Suit/L
# Product Price = $15.99
# Availability = In Stock.
