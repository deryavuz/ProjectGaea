# %% [markdown]
# ## Scraping for Amazon, Target data

# %% [markdown]
# ### This is the code for scraping a given search keyword URL on Amazon which populates a .csv file using the resulting data, such as availability, price, product ID etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import io
from urllib.request import urlopen
import csv

# %%
# Function to extract Product Title
def get_title(soup):
     
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
 
        # Inner NavigatableString Object
        title_value = title.string
 
        # Title as a string value
        title_string = title_value.strip()
 
 
    except AttributeError:
        title_string = ""   
 
    return title_string
 
# Function to extract Product Price
def get_price(soup):
 
    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()
 
    except AttributeError:
 
        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()
 
        except:     
            price = ""  
 
    return price
 
# Function to extract Product Rating
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
 
# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
 
# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
 
    except AttributeError:
        available = "Not Available"
 
    return available    
 
 
if __name__ == '__main__':
 
    # Headers for request
    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                'Accept-Language': 'en-US'})
 
    # The webpage URL
    URL = "https://www.amazon.com/s?k=ppe&ref=nb_sb_noss_2"
     
    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "lxml")
 
    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
 
    # Store the links
    links_list = []
 
    # Loop for extracting links from Tag Objects
    for link in links:
        links_list.append(link.get('href'))
 
 
    # Loop for extracting product details from each link 
    for link in links_list:
 
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)
 
        new_soup = BeautifulSoup(new_webpage.content, "lxml")
    
        curr_title = get_title(new_soup)
        curr_price = get_price(new_soup)
        curr_stock = get_availability(new_soup)
         
        # Function calls to display all necessary product information
        print("Product Title =", curr_title)
        print("Product Price =", curr_price)
        #print("Product Rating =", get_rating(new_soup))
        #print("Number of Product Reviews =", get_review_count(new_soup))
        print("Availability =", curr_stock)
        print()
        print()
        
        with open("heat.csv", "w", newline="", encoding='utf-8') as f_heat:
            csv_heat = csv.writer(f_heat)
            csv_heat.writerow(["Title", "Price", "In Stock?"])
            csv_heat.writerow([curr_title, curr_price, curr_stock])
    
    
        
        
#         with io.open('scraped_data', "w", encoding="utf-8") as f:
#             f.write(f"{curr_title},") 
#             f.write(f"{curr_price},") 
#             f.write(f"{curr_stock},\n")
#             f.close()
# Out:
# Product Title =
# Product Price =
# Availability = Not Available
#
#
# Product Title = Polyethylene Cover Gown - Case of 75 | 23GSM Disposable Gown with Sleeves, Easy Over the Head Feature and Waist Tie | Thumb Loop Enclosure for Increased Coverage | Business Friendly Pricing
# Product Price = $89.99
# Availability = In Stock.
#
#
# Product Title = 50 PCS Blue Face Masks, Non Woven Thick 3-Layers Breathable Facial Masks with Adjustable Earloop, Mouth and Nose Cover
# Product Price = $9.96
# Availability = In Stock.
#
#
# Product Title = PPE Kit All-in-One Personal Protection Kits to GO,10 Pack
# Product Price =
# Availability = In Stock.
#
#
# Product Title = All-in-One Personal Protection Kits to GO - 10 Pack - With Plastic Gloves, Hand Cleansing Wipes, Disposable Face Mask
# Product Price = $24.98
# Availability = In Stock.
#
#
# Product Title = 10pcs Glasses Face Shield Reusable Goggle Shields Replaceable Anti Fog Shields Transparent Face Shield Protect Face and Eyes for Women and Men (10, Transparent)
# Product Price = $17.99
# Availability = In Stock.
#
#
# Product Title = TCP Global Salon World Safety - Black Safety Face Masks Disposable 3-Ply PPE
# Product Price = $9.96
# Availability = In Stock.
#
#
# Product Title = hand2mind Polyethylene, Level 1, Disposable, Non-Surgical Isolation Gowns, Blue, Bag of 15
# Product Price = $14.44
# Availability = In Stock.
#
#
# Product Title = Ever Ready First Aid DYN2141-X10 Isolation Gown with Elastic Wrists, Universal Quantity, Yellow (Pack of 10)
# Product Price = $17.79
# Availability = In Stock.
#
#
# Product Title = PAGE ONE Disposable Isolation Suit,Long Front Zipper Elastic Waistband & Cuffs Protective Coverall Suit/L
# Product Price = $14.99
# Availability = In Stock.
#
#
# Product Title = Disposable Coverall with Hood - White (XXL)
# Product Price = $6.95
# Availability = In stock.
#
#
# Product Title = KwikSafety (Charlotte, NC) TURTLE SHELL COMBO (10 Vents) Standard Cap ANSI Hard Hat, Safety Glasses, Sunshade, Sweatband & Earplugs Construction Work PPE, Type1, Class C, WHITE
# Product Price = $25.99
# Availability = In Stock.
#
#
# Product Title = DuPont TY122S Disposable Elastic Wrist, Bootie & Hood White Tyvek Coverall Suit 1414, Large
# Product Price = $10.20
# Availability = In Stock.
#
#
# Product Title = 2000 PCS Black Disposable Face Masks (40 Packs, 50pcs/pack), Wholesale Bulk Disposable Mask, Non Woven Thick 3-Layers Masks Cup Dust Masks for Business School PPE
# Product Price = $199.98
# Availability = In Stock.
#
#
# Product Title = Suave Hand Sanitizer Alcohol Based Kills 99.9% of Germs 10 oz,Pack of 6
# Product Price = $26.32
# Availability = In Stock.
#
#
# Product Title = 50 Pcs Black Disposable Face Masks, 3 Ply Face Mask Breathable and Comfortable, Non Woven Thick 3-Layers Masks Cup Dust Masks PPE Black Maks - Box
# Product Price = $12.98
# Availability = In Stock.
#
#
# Product Title = PPE Kit All-in-One Personal Protection Kits to GO,10 Pack
# Product Price =
# Availability = In Stock.
#
#
# Product Title = Face Shields For Protection - Full Plastic Faceshields Guard Anti Fog Reusable PPE Transparent Safety Protective Clear Mask Medical Surgical Dental Eye Shield Women Men Kids - Made in USA - 3 Pack
# Product Price =
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask (30 Pack White), Individually Wrapped Protective Cup Mask, 5-Ply Breathable Layer Filter Efficiency≥95% Against PM2.5, Comfortable Safety Disposable KN95 Respirator Masks
# Product Price = $34.70
# Availability = In Stock.
#
#
# Product Title = 25 Pack KN95 Face Mask, Filter Efficiency≥95%, 5-Ply KN95 Mask Protection Against PM2.5, Fire Smoke, Dust Cup Dust Mask (Pink, Blue, Purple, Red, Gray)
# Product Price = $39.74
# Availability = In Stock.
#
#
# Product Title = Disposable Isolation Gown Polypropylene Lab Gowns Knit Cuff Long Sleeve Blue 10 Pack
# Product Price = $16.54
# Availability = In Stock.
#
#
# Product Title = Face Shield for Protection with Glasses Reusable Clear Mask 10 PCS Anti-Fog No Installation Required with Comfortable Sponge and Elastic Band for Women Men
# Product Price = $11.99
# Availability = In Stock.
#
#
# Product Title = Milliard Washable, Waterproof Isolation Gown - Reusable Up to 50 Washes-200 GOWNS | Universal Size | White
# Product Price = $745.99
# Availability = In Stock.
#
#
# Product Title = Hotodeal KN95 Face Mask 20 PCS, Filter Efficiency≥95%, 5 Ply Mask Against PM2.5
# Product Price = $36.99
# Availability = In Stock.
#
#
# Product Title = Reusable Half Face Cover NASUM Half Face Cover wiith Safety Glasses,Paint Face Cover for Painting, Machine Polishing, Welding and Other Work Protection(Medium)
# Product Price = $24.49
# Availability = In Stock.
#
#
# Product Title = 10 Pack Disposable Protection Gowns, Adult Isolation Non-Woven Aprons, Long Sleeves, Neck and Waist Ties, Fully Closed, Knitted Cuffs Fluid Resistant for Non-Sterile Examinations, Lab and Visitor Coat
# Product Price =
# Availability = In Stock.
#
#
# Product Title = Safety Goggles, Anti-Fog Eye Protection Glasses, Lightweight Dustproof Over-Glasses, Anti-Splash Goggles for Men and Women 3 Pack
# Product Price = $15.99
# Availability = In Stock.
#
#
# Product Title = Safety Face Shields 10 Pack, Protective Face Shield Mask with Clear Wide Visor, Lightweight Transparent Dustproof Windproof Full Face Shield, Elastic Band for Women Men with 2 Protective Films
# Product Price =
# Availability = In Stock.
#
#
# Product Title = Bigox Face Mask Disposable Earloop Blue 50Pcs
# Product Price = $9.99
# Availability = In Stock.
#
#
# Product Title = WeCare Individually Wrapped Disposable Face Masks - 50 Pack, Black -Soft on Skin - 3 Ply Protectors with Elastic Earloops - Latex Free, Non Woven, Single Use - Effective Filtration - Retail Packaging
# Product Price =
# Availability = In Stock.
#
#
# Product Title = PURELL Advanced Hand Sanitizer, Refreshing Gel, 12 fl oz Sanitizer Table Top Pump Bottle (Case of 12) - 3659-12
# Product Price = $59.90
# Availability = In Stock.
#
#
# Product Title = NanoBio Protect Nasal Antiseptic | Reduces The Risk of Respiratory Infection | Kills 99.99% of Germs | 8 Hour Protection | Safe for Kids, Daily Use | Nasal Disinfectant | 40+ Uses | FSA/HSA Eligible
# Product Price = $16.95
# Availability = In Stock.
#
#
# Product Title = PAGE ONE Disposable Isolation Suit,Long Front Zipper Elastic Waistband & Cuffs Protective Coverall Suit/L
# Product Price = $14.99
# Availability = In Stock.
#
#
# Product Title = ISAMANNER 100pcs Mouth Covers
# Product Price = $11.39
# Availability = In Stock.
#
#
# Product Title = 50-Pack Disposable Isolation Gown, FDA Registered, CE certified Level 2 PP & PE 40g, Fully Closed Double Tie Back, Knitted Cuffs, Fluid Resistant, Unisex
# Product Price =
# Availability = In Stock.
#
#
# Product Title = CARESTREAM Shield - Made in USA Durable Face Shield Protection, Lightweight Comfortable Reusable Adjustable Cleanable Plastic, Fits Glasses & Loupes, Clear Replaceable Shield | Incl 1 HOLDER 2 SHIELDS
# Product Price = $15.99
# Availability = In Stock.
#
#
# Product Title = Karalai Washable, Waterproof Isolation Gown - Reusable Up to 50 Washes | Universal Size | 10 per Case (Blue)
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = Oceantree Shoe Covers Disposable -100 Pack (50 Pairs) Disposable Shoe & Boot Covers Waterproof Slip Resistant Non Slip, Durable Boot&Shoes Cover, One Size Fits All (Clear Blue) (CPE Plastic)
# Product Price = $10.99
# Availability = In Stock.
#
#
# Product Title = OUBA [6 PACK] Anti Air Dust Reusable Glasses Style Visor Transparent Cover,Unisex Mouth Cover, Fashion Protective
# Product Price = $12.99
# Availability = In Stock.
#
#
# Product Title = Single Use Disposable Face Mask (Pack of 50), Blue
# Product Price = $7.99
# Availability = In Stock.
#
#
# Product Title = Karalai Washable, Waterproof Isolation Gown - Reusable Up to 50 Washes | Universal Size | 10 per Case (Blue)
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = OMK 2 Pcs Reusable Face Shields
# Product Price = $6.99
# Availability = In Stock.
#
#
# Product Title = InterMask ASTM Level 3 Disposable 3 Ply Face Masks, More Than 98% Filtration Efficiency, Box Of 50 pcs
# Product Price = $16.99
# Availability = In Stock.
#
#
# Product Title = SMS Disposable Isolation Gown Splash Resistant with Hood White Medium
# Product Price = $19.99
# Availability = In Stock.
#
#
# Product Title = 50 PCS Blue Face Masks, Non Woven Thick 3-Layers Breathable Facial Masks with Adjustable Earloop, Mouth and Nose Cover
# Product Price = $9.96
# Availability = In Stock.
# Product Title = Zubrex 50 Pcs Disposable 3 Ply Safety Face Mask for Protection - with Nanofiber Lining Elastic Earloops, Lightweight Breathable Protective Anti-Dust Facial Masks Health School Office
# Product Price = $12.98
# Availability = In Stock.
#
#
# Product Title = BLScode Disposable Face Protective Masks, 3-Layer Facial Cover Masks with Elastic Ear Loops, Comfortable Universal Design for Adults & Kids, Suitable for Home, Office, Outdoor (Pack of 50)
# Product Price = $11.99
# Availability = In Stock.
#
#
# Product Title = TCP Global Salon World Safety - Kids Face Masks 150 Pk 3-Ply Protective PPE (5 Colors, 30 Each)
# Product Price = $29.96
# Availability = In Stock.
#
#
# Product Title = TCP Global Salon World Safety - Sealed Dispenser Box of 50 Face Masks Breathable Disposable 3-Ply Protective PPE with Nose Clip and Ear Loops
# Product Price = $9.96
# Availability = In Stock.
#
#
# Product Title = Pacific PPE 4Pairs Cleaning Glove Reusable Household Dishwashing Gloves-Latex Free Waterproof PVC Gloves for Kitchen,Gardening Gloves Unlined(Blue,L)
# Product Price =
# Availability = In Stock.
#
#
# Product Title = CapLens Full Face Shield Cap Accessory, Anti-Fog, Adjustable, Reusable, Slip onto Your Existing Cap Black
# Product Price = $17.95
# Availability = In Stock.
#
#
# Product Title = 2000 PCS Bulk Blue Face Masks (40 Boxes, 50pcs/Box), Non Woven Thick 3-Layers Breathable Facial Masks with Adjustable Earloop, Mouth and Nose Cover
# Product Price = $139.98
# Availability = In Stock.
#
#
# Product Title = magent Isolation Gowns - Disposable, Non-Woven, La//te X Free, SplashResistant, E//lastic K//nit Cuff Gowns(Universal Quantity, 10 Per Case/150cm Long
# Product Price = $14.50
# Availability = In Stock.
#
#
# Product Title = 10 Pcs Milliard Reusable, Washable, Waterproof Polyester Isolation Gown - Reusable Up to 50 Washes | Universal Size | White
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = Pack of 10 Disposable Isolation Gowns with Elastic Cuff, Knitted Cuff, Late x- Free, Non-Woven, FluidResistant, Dental, Hospital, Industries, ONE SIZE FITS ALL(10 PCS=1 Bag), BLUE
# Product Price = $16.00
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask - 50pcs Cup Dust Mask KN95, 5-Ply Layer Filter, Against PM2.5 Dust Disposable Respirator KN95 Mask White
# Product Price = $49.07
# Availability = In Stock.
#
#
# Product Title = Ever Ready First Aid DYN2141-X10 Isolation Gown with Elastic Wrists, Universal Quantity, Yellow (Pack of 10)
# Product Price = $17.79
# Availability = In Stock.
#
#
# Product Title = KN95 Face Mask 40 PCs, Filter Efficiency≥95%, 5 Layers Cup Dust Mask, Masks Against PM2.5 from Fire Smoke, Dust, for Men, Women, Healthcare Worker, Essential Workers(White)
# Product Price = $39.99
# Availability = In Stock.
#
#
# Product Title = Dynatomy Face Shields, 10-pack, Made in USA, Full Coverage PPE by D'Addario (DFSM-1-10)
# Product Price = $18.90
# Availability = In Stock.
#
#
# Product Title = Caresour Advanced 75% Alcohol Hand Sanitizer Wipes, 4 Packs of 50 (200 Wipes)
# Product Price = $18.99
# Availability = In Stock.
#
#
# Product Title = Disposable Isolation Gown Size: Universal Qty: 50 per Case (Blue)
# Product Price = $89.99
# Availability = In Stock.
#
#
# Product Title = SUMMIT PERSON Personal Protective Equipment PPE Disposable Face Mask 50 Count (Black)
# Product Price = $12.99
# Availability = In Stock.
#
#
# Product Title = All-in-One Personal Protection Kits to GO - 10 Pack - With Plastic Gloves, Hand Cleansing Wipes, Disposable Face Mask
# Product Price = $24.98
# Availability = In Stock.
#
#
# Product Title = TCP Global Salon World Safety Face Shields with All Clear Glasses Frames (Pack of 4) - Ultra Clear Protective Full Face Shields to Protect Eyes, Nose, Mouth - Anti-Fog PET Plastic, Goggles
# Product Price = $8.96
# Availability = In Stock.
#
#
# Product Title = PAGE ONE Disposable Isolation Suit,Long Front Zipper Elastic Waistband & Cuffs Protective Coverall Suit/L
# Product Price = $14.99
# Availability = In Stock.
#
#
# Product Title = ZShield Ultra - Reusable Face Shield w/Full-Face Clear Lens & Forehead Mounted Design (Wear with Glasses, Ear-to-Ear Coverage, Made in USA, 2 Pack)
# Product Price = $37.98
# Availability = In Stock.

# %%
# Convert the extracted data to pandas dataframe for ease of use.
amazon_scrape = pd.read_csv("heat.csv") 
# Preview the first 5 lines of the loaded data 
amazon_scrape
# Out:
#                                                Title   Price  In Stock?
# 0  Patriot Face Cover, Made in USA, NIOSH Approve...  $84.95  In Stock.
